# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\kang8\\Downloads'

# %%
import pandas as pd

# %%
pd.read_excel("BTC-USD.xlsx").head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#        Volume
# 0  21056800.0
# 1  34483200.0
# 2  37919700.0
# 3  36863600.0
# 4  26580100.0

# %%
BTC = pd.read_excel("BTC-USD.xlsx")

# %%
BTC.head(3)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
#
#        Volume
# 0  21056800.0
# 1  34483200.0
# 2  37919700.0

# %%
BTC.shape
# Out:
# (2437, 7)

# %%
import pandas as pd
import numpy as np

# %%
inputs = {
    'open': np.random.random(5),
    'high': np.random.random(5),
    'low': np.random.random(5),
    'close': np.random.random(5),
    'volume': np.random.random(5)
}

# %%
print(type(inputs))
inputs
# Out:
# <class 'dict'>
# {'open': array([0.33076227, 0.93603845, 0.65733673, 0.17969386, 0.70022552]),
#  'high': array([0.84264391, 0.73647768, 0.12754837, 0.72325054, 0.67997653]),
#  'low': array([0.22965213, 0.091683  , 0.23707431, 0.64901928, 0.35799781]),
#  'close': array([0.12424276, 0.34640554, 0.70386894, 0.82338396, 0.8315118 ]),
#  'volume': array([0.27137823, 0.13191529, 0.0057042 , 0.32917335, 0.09786191])}

# %%
print(type(inputs["open"]))
inputs["open"]
# Out:
# <class 'numpy.ndarray'>
# array([0.33076227, 0.93603845, 0.65733673, 0.17969386, 0.70022552])

# %%
print(type(np.random.random(5)))
np.random.random(5)
# Out:
# <class 'numpy.ndarray'>
# array([0.17122087, 0.03265149, 0.52996273, 0.09918841, 0.82851007])

# %%
BTC.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#        Volume
# 0  21056800.0
# 1  34483200.0
# 2  37919700.0
# 3  36863600.0
# 4  26580100.0

# %%
print(type(BTC["Open"]))
BTC["Open"]
# Out:
# <class 'pandas.core.series.Series'>
# 0         465.864014
# 1         456.859985
# 2         424.102997
# 3         394.673004
# 4         408.084991
#             ...
# 2432    49855.496094
# 2433    46716.636719
# 2434    46415.898438
# 2435    43488.058594
# 2436    42673.000000
# Name: Open, Length: 2437, dtype: float64

# %%
inputs = {
    'open': BTC["Open"],
    'high': BTC["High"],
    'low':  BTC["Low"],
    'close':  BTC["Adj Close"],
    'volume': BTC["Volume"]
}

# %%
from talib.abstract import
# Out:
#   File "<ipython-input-17-eeb29607f05a>", line 1
#     from talib.abstract import
#                                ^
# SyntaxError: invalid syntax

# %%
inputs["open"]
# Out:
# 0         465.864014
# 1         456.859985
# 2         424.102997
# 3         394.673004
# 4         408.084991
#             ...
# 2432    49855.496094
# 2433    46716.636719
# 2434    46415.898438
# 2435    43488.058594
# 2436    42673.000000
# Name: Open, Length: 2437, dtype: float64

# %%
pd.isna(BTC)
# Out:
#        Date   Open   High    Low  Close  Adj Close  Volume
# 0     False  False  False  False  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False  False  False  False  False      False   False
# ...     ...    ...    ...    ...    ...        ...     ...
# 2432  False  False  False  False  False      False   False
# 2433  False  False  False  False  False      False   False
# 2434  False  False  False  False  False      False   False
# 2435  False  False  False  False  False      False   False
# 2436  False  False  False  False  False      False   False
#
# [2437 rows x 7 columns]

# %%
BTC.isnull().values.any()
# Out:
# True

# %%
pd.DataFrame(BTC).dropna()
# Out:
#            Date          Open          High           Low         Close  \
# 0    2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1    2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2    2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3    2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4    2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...         ...           ...           ...           ...           ...
# 2432 2021-05-15  49855.496094  50639.664063  46664.140625  46760.187500
# 2433 2021-05-16  46716.636719  49720.042969  43963.351563  46456.058594
# 2434 2021-05-17  46415.898438  46623.558594  42207.289063  43537.511719
# 2435 2021-05-18  43488.058594  45812.457031  42367.832031  42909.402344
# 2436 2021-05-19  42673.000000  43546.117188  38787.902344  40330.925781
#
#          Adj Close        Volume
# 0       457.334015  2.105680e+07
# 1       424.440002  3.448320e+07
# 2       394.795990  3.791970e+07
# 3       408.903992  3.686360e+07
# 4       398.821014  2.658010e+07
# ...            ...           ...
# 2432  46760.187500  5.916105e+10
# 2433  46456.058594  6.404787e+10
# 2434  43537.511719  7.490364e+10
# 2435  42909.402344  5.618737e+10
# 2436  40330.925781  6.966838e+10
#
# [2433 rows x 7 columns]

# %%
modify_BTC = pd.DataFrame(BTC).dropna()

# %%
modify_BTC = modify_BTC.reset_index().drop(columns=['index'])

# %%
modify_BTC
# Out:
#            Date          Open          High           Low         Close  \
# 0    2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1    2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2    2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3    2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4    2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...         ...           ...           ...           ...           ...
# 2428 2021-05-15  49855.496094  50639.664063  46664.140625  46760.187500
# 2429 2021-05-16  46716.636719  49720.042969  43963.351563  46456.058594
# 2430 2021-05-17  46415.898438  46623.558594  42207.289063  43537.511719
# 2431 2021-05-18  43488.058594  45812.457031  42367.832031  42909.402344
# 2432 2021-05-19  42673.000000  43546.117188  38787.902344  40330.925781
#
#          Adj Close        Volume
# 0       457.334015  2.105680e+07
# 1       424.440002  3.448320e+07
# 2       394.795990  3.791970e+07
# 3       408.903992  3.686360e+07
# 4       398.821014  2.658010e+07
# ...            ...           ...
# 2428  46760.187500  5.916105e+10
# 2429  46456.058594  6.404787e+10
# 2430  43537.511719  7.490364e+10
# 2431  42909.402344  5.618737e+10
# 2432  40330.925781  6.966838e+10
#
# [2433 rows x 7 columns]

# %%
inputs = {
    'open': modify_BTC["Open"],
    'high': modify_BTC["High"],
    'low':  modify_BTC["Low"],
    'close':  modify_BTC["Adj Close"],
    'volume': modify_BTC["Volume"]
}

# %%
pd.DataFrame(SMA(inputs, timeperiod = 5, price='open')).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-dba31c78b475> in <module>
# ----> 1 pd.DataFrame(SMA(inputs, timeperiod = 5, price='open')).head(10)
#
# NameError: name 'SMA' is not defined

# %%
open_5ma   = SMA(inputs, timeperiod = 5, price='open')
close_5ma  = SMA(inputs, timeperiod = 5, price='close')
close_10ma = SMA(inputs, timeperiod = 10, price='close')
close_20ma = SMA(inputs, timeperiod = 20, price='close')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-276c0ee346a4> in <module>
# ----> 1 open_5ma   = SMA(inputs, timeperiod = 5, price='open')
#       2 close_5ma  = SMA(inputs, timeperiod = 5, price='close')
#       3 close_10ma = SMA(inputs, timeperiod = 10, price='close')
#       4 close_20ma = SMA(inputs, timeperiod = 20, price='close')
#
# NameError: name 'SMA' is not defined

# %%
modify_BTC.head(3)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
#
#        Volume
# 0  21056800.0
# 1  34483200.0
# 2  37919700.0

# %%
open_5ma
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-d4f422815562> in <module>
# ----> 1 open_5ma
#
# NameError: name 'open_5ma' is not defined

# %%
modify_BTC["open_5ma"] = open_5ma
modify_BTC["close_5ma"] = open_5ma
modify_BTC["close_10ma"] = open_5ma
modify_BTC["close_20ma"] = open_5ma
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-62fcede14a8f> in <module>
# ----> 1 modify_BTC["open_5ma"] = open_5ma
#       2 modify_BTC["close_5ma"] = open_5ma
#       3 modify_BTC["close_10ma"] = open_5ma
#       4 modify_BTC["close_20ma"] = open_5ma
#
# NameError: name 'open_5ma' is not defined

# %%
modify_BTC
# Out:
#            Date          Open          High           Low         Close  \
# 0    2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1    2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2    2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3    2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4    2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...         ...           ...           ...           ...           ...
# 2428 2021-05-15  49855.496094  50639.664063  46664.140625  46760.187500
# 2429 2021-05-16  46716.636719  49720.042969  43963.351563  46456.058594
# 2430 2021-05-17  46415.898438  46623.558594  42207.289063  43537.511719
# 2431 2021-05-18  43488.058594  45812.457031  42367.832031  42909.402344
# 2432 2021-05-19  42673.000000  43546.117188  38787.902344  40330.925781
#
#          Adj Close        Volume
# 0       457.334015  2.105680e+07
# 1       424.440002  3.448320e+07
# 2       394.795990  3.791970e+07
# 3       408.903992  3.686360e+07
# 4       398.821014  2.658010e+07
# ...            ...           ...
# 2428  46760.187500  5.916105e+10
# 2429  46456.058594  6.404787e+10
# 2430  43537.511719  7.490364e+10
# 2431  42909.402344  5.618737e+10
# 2432  40330.925781  6.966838e+10
#
# [2433 rows x 7 columns]

# %%
modify_BTC["y"] = None

# %%
modify_BTC
# Out:
#            Date          Open          High           Low         Close  \
# 0    2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1    2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2    2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3    2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4    2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...         ...           ...           ...           ...           ...
# 2428 2021-05-15  49855.496094  50639.664063  46664.140625  46760.187500
# 2429 2021-05-16  46716.636719  49720.042969  43963.351563  46456.058594
# 2430 2021-05-17  46415.898438  46623.558594  42207.289063  43537.511719
# 2431 2021-05-18  43488.058594  45812.457031  42367.832031  42909.402344
# 2432 2021-05-19  42673.000000  43546.117188  38787.902344  40330.925781
#
#          Adj Close        Volume     y
# 0       457.334015  2.105680e+07  None
# 1       424.440002  3.448320e+07  None
# 2       394.795990  3.791970e+07  None
# 3       408.903992  3.686360e+07  None
# 4       398.821014  2.658010e+07  None
# ...            ...           ...   ...
# 2428  46760.187500  5.916105e+10  None
# 2429  46456.058594  6.404787e+10  None
# 2430  43537.511719  7.490364e+10  None
# 2431  42909.402344  5.618737e+10  None
# 2432  40330.925781  6.966838e+10  None
#
# [2433 rows x 8 columns]

# %%
import math

# %%
math.log(120, 10)
# Out:
# 2.0791812460476247

# %%
modify_BTC.iloc[1, 5]
# Out:
# 424.440002

# %%
math.log( modify_BTC.iloc[1, 5]/modify_BTC.iloc[0, 5] , 10)
# Out:
# -0.03241719606846411

# %%
modify_BTC.shape[0]
# Out:
# 2433

# %%
for i in range(0, modify_BTC.shape[0]-1):
    modify_BTC.iloc[i, -1] = math.log( modify_BTC.iloc[i+1, 5]/modify_BTC.iloc[i, 5] , 10)

# %%
modify_BTC
# Out:
#            Date          Open          High           Low         Close  \
# 0    2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1    2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2    2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3    2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4    2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...         ...           ...           ...           ...           ...
# 2428 2021-05-15  49855.496094  50639.664063  46664.140625  46760.187500
# 2429 2021-05-16  46716.636719  49720.042969  43963.351563  46456.058594
# 2430 2021-05-17  46415.898438  46623.558594  42207.289063  43537.511719
# 2431 2021-05-18  43488.058594  45812.457031  42367.832031  42909.402344
# 2432 2021-05-19  42673.000000  43546.117188  38787.902344  40330.925781
#
#          Adj Close        Volume           y
# 0       457.334015  2.105680e+07  -0.0324172
# 1       424.440002  3.448320e+07  -0.0314436
# 2       394.795990  3.791970e+07   0.0152486
# 3       408.903992  3.686360e+07  -0.0108433
# 4       398.821014  2.658010e+07  0.00361221
# ...            ...           ...         ...
# 2428  46760.187500  5.916105e+10 -0.00283388
# 2429  46456.058594  6.404787e+10  -0.0281788
# 2430  43537.511719  7.490364e+10 -0.00631114
# 2431  42909.402344  5.618737e+10  -0.0269143
# 2432  40330.925781  6.966838e+10        None
#
# [2433 rows x 8 columns]

# %%
modify_BTC.dropna()
# Out:
#            Date          Open          High           Low         Close  \
# 0    2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1    2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2    2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3    2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4    2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...         ...           ...           ...           ...           ...
# 2427 2021-05-14  49682.980469  51438.117188  48868.578125  49880.535156
# 2428 2021-05-15  49855.496094  50639.664063  46664.140625  46760.187500
# 2429 2021-05-16  46716.636719  49720.042969  43963.351563  46456.058594
# 2430 2021-05-17  46415.898438  46623.558594  42207.289063  43537.511719
# 2431 2021-05-18  43488.058594  45812.457031  42367.832031  42909.402344
#
#          Adj Close        Volume           y
# 0       457.334015  2.105680e+07  -0.0324172
# 1       424.440002  3.448320e+07  -0.0314436
# 2       394.795990  3.791970e+07   0.0152486
# 3       408.903992  3.686360e+07  -0.0108433
# 4       398.821014  2.658010e+07  0.00361221
# ...            ...           ...         ...
# 2427  49880.535156  5.573750e+10  -0.0280549
# 2428  46760.187500  5.916105e+10 -0.00283388
# 2429  46456.058594  6.404787e+10  -0.0281788
# 2430  43537.511719  7.490364e+10 -0.00631114
# 2431  42909.402344  5.618737e+10  -0.0269143
#
# [2432 rows x 8 columns]

# %%
modify_BTC = modify_BTC.dropna()

# %%
modify_BTC.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#        Volume           y
# 0  21056800.0  -0.0324172
# 1  34483200.0  -0.0314436
# 2  37919700.0   0.0152486
# 3  36863600.0  -0.0108433
# 4  26580100.0  0.00361221

# %%
modify_BTC.tail()
# Out:
#            Date          Open          High           Low         Close  \
# 2427 2021-05-14  49682.980469  51438.117188  48868.578125  49880.535156
# 2428 2021-05-15  49855.496094  50639.664063  46664.140625  46760.187500
# 2429 2021-05-16  46716.636719  49720.042969  43963.351563  46456.058594
# 2430 2021-05-17  46415.898438  46623.558594  42207.289063  43537.511719
# 2431 2021-05-18  43488.058594  45812.457031  42367.832031  42909.402344
#
#          Adj Close        Volume           y
# 2427  49880.535156  5.573750e+10  -0.0280549
# 2428  46760.187500  5.916105e+10 -0.00283388
# 2429  46456.058594  6.404787e+10  -0.0281788
# 2430  43537.511719  7.490364e+10 -0.00631114
# 2431  42909.402344  5.618737e+10  -0.0269143

# %%
modify_BTC
# Out:
#            Date          Open          High           Low         Close  \
# 0    2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1    2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2    2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3    2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4    2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...         ...           ...           ...           ...           ...
# 2427 2021-05-14  49682.980469  51438.117188  48868.578125  49880.535156
# 2428 2021-05-15  49855.496094  50639.664063  46664.140625  46760.187500
# 2429 2021-05-16  46716.636719  49720.042969  43963.351563  46456.058594
# 2430 2021-05-17  46415.898438  46623.558594  42207.289063  43537.511719
# 2431 2021-05-18  43488.058594  45812.457031  42367.832031  42909.402344
#
#          Adj Close        Volume           y
# 0       457.334015  2.105680e+07  -0.0324172
# 1       424.440002  3.448320e+07  -0.0314436
# 2       394.795990  3.791970e+07   0.0152486
# 3       408.903992  3.686360e+07  -0.0108433
# 4       398.821014  2.658010e+07  0.00361221
# ...            ...           ...         ...
# 2427  49880.535156  5.573750e+10  -0.0280549
# 2428  46760.187500  5.916105e+10 -0.00283388
# 2429  46456.058594  6.404787e+10  -0.0281788
# 2430  43537.511719  7.490364e+10 -0.00631114
# 2431  42909.402344  5.618737e+10  -0.0269143
#
# [2432 rows x 8 columns]

# %%
modify_BTC.iloc[:, -5:-1]
# Out:
#                Low         Close     Adj Close        Volume
# 0       452.421997    457.334015    457.334015  2.105680e+07
# 1       413.104004    424.440002    424.440002  3.448320e+07
# 2       384.532013    394.795990    394.795990  3.791970e+07
# 3       389.882996    408.903992    408.903992  3.686360e+07
# 4       393.181000    398.821014    398.821014  2.658010e+07
# ...            ...           ...           ...           ...
# 2427  48868.578125  49880.535156  49880.535156  5.573750e+10
# 2428  46664.140625  46760.187500  46760.187500  5.916105e+10
# 2429  43963.351563  46456.058594  46456.058594  6.404787e+10
# 2430  42207.289063  43537.511719  43537.511719  7.490364e+10
# 2431  42367.832031  42909.402344  42909.402344  5.618737e+10
#
# [2432 rows x 4 columns]

# %%
X = modify_BTC.iloc[:, -5:-1]

# %%
modify_BTC['y']
# Out:
# 0       -0.0324172
# 1       -0.0314436
# 2        0.0152486
# 3       -0.0108433
# 4       0.00361221
#            ...
# 2427    -0.0280549
# 2428   -0.00283388
# 2429    -0.0281788
# 2430   -0.00631114
# 2431    -0.0269143
# Name: y, Length: 2432, dtype: object

# %%
y = modify_BTC['y']

# %%
X.shape
# Out:
# (2432, 4)

# %%
y.shape
# Out:
# (2432,)

# %%
X.iloc[:1214, :]
# Out:
#                Low         Close     Adj Close        Volume
# 0       452.421997    457.334015    457.334015  2.105680e+07
# 1       413.104004    424.440002    424.440002  3.448320e+07
# 2       384.532013    394.795990    394.795990  3.791970e+07
# 3       389.882996    408.903992    408.903992  3.686360e+07
# 4       393.181000    398.821014    398.821014  2.658010e+07
# ...            ...           ...           ...           ...
# 1209  14208.200195  15170.099609  15170.099609  1.841390e+10
# 1210  14424.000000  14595.400391  14595.400391  1.666000e+10
# 1211  13691.200195  14973.299805  14973.299805  1.850080e+10
# 1212  13105.900391  13405.799805  13405.799805  1.653410e+10
# 1213  13158.099609  13980.599609  13980.599609  1.206570e+10
#
# [1214 rows x 4 columns]

# %%
X_train = X.iloc[:1214, :]

# %%
X.iloc[1214:, :]
# Out:
#                Low         Close     Adj Close        Volume
# 1214  13952.400391  14360.200195  14360.200195  1.276360e+10
# 1215  13268.000000  13772.000000  13772.000000  1.108410e+10
# 1216  13641.700195  13819.799805  13819.799805  1.275080e+10
# 1217  10194.900391  11490.500000  11490.500000  1.885380e+10
# 1218   9402.290039  11188.599609  11188.599609  1.883060e+10
# ...            ...           ...           ...           ...
# 2427  48868.578125  49880.535156  49880.535156  5.573750e+10
# 2428  46664.140625  46760.187500  46760.187500  5.916105e+10
# 2429  43963.351563  46456.058594  46456.058594  6.404787e+10
# 2430  42207.289063  43537.511719  43537.511719  7.490364e+10
# 2431  42367.832031  42909.402344  42909.402344  5.618737e+10
#
# [1218 rows x 4 columns]

# %%
X_test = X.iloc[1214:, :]

# %%
y.iloc[:1214]
# Out:
# 0       -0.0324172
# 1       -0.0314436
# 2        0.0152486
# 3       -0.0108433
# 4       0.00361221
#            ...
# 1209    -0.0167724
# 1210     0.0111015
# 1211    -0.0480248
# 1212     0.0182331
# 1213     0.0116347
# Name: y, Length: 1214, dtype: object

# %%
y_train = y.iloc[:1214]

# %%
y.iloc[1214:]
# Out:
# 1214    -0.0181635
# 1215    0.00150474
# 1216    -0.0801628
# 1217    -0.0115632
# 1218     0.0109732
#            ...
# 2427    -0.0280549
# 2428   -0.00283388
# 2429    -0.0281788
# 2430   -0.00631114
# 2431    -0.0269143
# Name: y, Length: 1218, dtype: object

# %%
y_test = y.iloc[1214:]

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1214, 4)
# (1218, 4)
# (1214,)
# (1218,)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
reg.predict(X_train)
# Out:
# array([ 0.00089097,  0.00087581,  0.0008369 , ..., -0.0020279 ,
#        -0.00622939,  0.00285593])

# %%
reg.predict(X_train).size
# Out:
# 1214

# %%
y_train.to_numpy()
# Out:
# array([-0.03241719606846411, -0.031443575080708004, 0.015248617626229791,
#        ..., -0.04802479080909619, 0.01823306852573096,
#        0.011634696319410408], dtype=object)

# %%
from sklearn.metrics import mean_squared_error

# %%
y_true_train = y_train.to_numpy()
y_pred_train = reg.predict(X_train)
print("regression train mse: ", round(mean_squared_error(y_true_train, y_pred_train), 10))
# Out:
# regression train mse:  0.0002759729

# %%
y_true_test = y_test.to_numpy()
y_pred_test = reg.predict(X_test)
print("regression test mse: ", round(mean_squared_error(y_true_test, y_pred_test), 10))
# Out:
# regression test mse:  0.000961925

# %%
result = []
row = []
row.append("regression train mse: ")
row.append(round(mean_squared_error(y_true_train, y_pred_train), 10))
result.append(row)
row = []
row.append("regression test mse: ")
row.append(round(mean_squared_error(y_true_test, y_pred_test), 10))
result.append(row)
pd.DataFrame(result)
# Out:
#                         0         1
# 0  regression train mse:   0.000276
# 1   regression test mse:   0.000962

# %%
from sklearn import linear_model
reg = linear_model.Lasso(alpha=0.1)
reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_true_train = y_train.to_numpy()
y_pred_train = reg.predict(X_train)
print("lasso regression train mse: ", round(mean_squared_error(y_true_train, y_pred_train), 10))
# Out:
# lasso regression train mse:  0.0002766001

# %%
y_true_test = y_test.to_numpy()
y_pred_test = reg.predict(X_test)
print("lasso regression test mse: ", round(mean_squared_error(y_true_test, y_pred_test), 10))
# Out:
# lasso regression test mse:  0.0005912816

# %%
result = []
row = []
row.append("regression train mse: ")
row.append(round(mean_squared_error(y_true_train, y_pred_train), 10))
result.append(row)
row = []
row.append("regression test mse: ")
row.append(round(mean_squared_error(y_true_test, y_pred_test), 10))
result.append(row)
pd.DataFrame(result)
# Out:
#                         0         1
# 0  regression train mse:   0.000277
# 1   regression test mse:   0.000591

# %%
from sklearn import tree
reg = tree.DecisionTreeRegressor()
reg = reg.fit(X_train, y_train)

# %%
y_true_train = y_train.to_numpy()
y_pred_train = reg.predict(X_train)
print("lasso regression train mse: ", round(mean_squared_error(y_true_train, y_pred_train), 10))
y_true_test = y_test.to_numpy()
y_pred_test = reg.predict(X_test)
print("lasso regression test mse: ", round(mean_squared_error(y_true_test, y_pred_test), 10))
result = []
row = []
row.append("regression train mse: ")
row.append(round(mean_squared_error(y_true_train, y_pred_train), 10))
result.append(row)
row = []
row.append("regression test mse: ")
row.append(round(mean_squared_error(y_true_test, y_pred_test), 10))
result.append(row)
pd.DataFrame(result)
# Out:
# lasso regression train mse:  0.0
# lasso regression test mse:  0.0011116964
#                         0         1
# 0  regression train mse:   0.000000
# 1   regression test mse:   0.001112
